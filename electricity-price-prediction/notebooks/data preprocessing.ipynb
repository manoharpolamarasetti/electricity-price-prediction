# %%
import pandas as pd


# Load the Excel files
df_2009 = pd.read_csv(r"C:\Users\t10mp22\OneDrive - University of Aberdeen\Project\Demand data\demanddata_2009.csv")
df_2010 = pd.read_csv(r"C:\Users\t10mp22\OneDrive - University of Aberdeen\Project\Demand data\demanddata_2010 (1).csv")
df_2011 = pd.read_csv(r"C:\Users\t10mp22\OneDrive - University of Aberdeen\Project\Demand data\demanddata_2011.csv")
df_2012 = pd.read_csv(r"C:\Users\t10mp22\OneDrive - University of Aberdeen\Project\Demand data\demanddata_2012.csv")
df_2013 = pd.read_csv(r"C:\Users\t10mp22\OneDrive - University of Aberdeen\Project\Demand data\demanddata_2013.csv")
df_2014 = pd.read_csv(r"C:\Users\t10mp22\OneDrive - University of Aberdeen\Project\Demand data\demanddata_2014.csv")
df_2015 = pd.read_csv(r"C:\Users\t10mp22\OneDrive - University of Aberdeen\Project\Demand data\demanddata_2015.csv")
df_2016 = pd.read_csv(r"C:\Users\t10mp22\OneDrive - University of Aberdeen\Project\Demand data\demanddata_2016.csv")
df_2017 = pd.read_csv(r"C:\Users\t10mp22\OneDrive - University of Aberdeen\Project\Demand data\demanddata_2017.csv")
df_2018 = pd.read_csv(r"C:\Users\t10mp22\OneDrive - University of Aberdeen\Project\Demand data\demanddata_2018.csv")
df_2019 = pd.read_csv(r"C:\Users\t10mp22\OneDrive - University of Aberdeen\Project\Demand data\demanddata_2019.csv")
df_2020 = pd.read_csv(r"C:\Users\t10mp22\OneDrive - University of Aberdeen\Project\Demand data\demanddata_2020.csv")
df_2021 = pd.read_csv(r"C:\Users\t10mp22\OneDrive - University of Aberdeen\Project\Demand data\demanddata_2021.csv")
df_2022 = pd.read_csv(r"C:\Users\t10mp22\OneDrive - University of Aberdeen\Project\Demand data\demanddata_2022.csv")
df_2023 = pd.read_csv(r"C:\Users\t10mp22\OneDrive - University of Aberdeen\Project\Demand data\demanddata_2023.csv")


# Combine the DataFrames
combined_df = pd.concat([df_2009, df_2010, df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2017, df_2018, df_2019, df_2020, df_2021, df_2022, df_2023], ignore_index=True)

# Save the combined DataFrame to a new Excel file
combined_file_path = r"C:\Users\t10mp22\OneDrive - University of Aberdeen\Project\demand dat 2009 to 2023.csv"
combined_df.to_csv(combined_file_path, index=False)

# %%
combined_df
# Out:
#        SETTLEMENT_DATE  SETTLEMENT_PERIOD     ND    TSD  ENGLAND_WALES_DEMAND  \
# 0          01-JAN-2009                  1  37910  38704                 33939
# 1          01-JAN-2009                  2  38047  38964                 34072
# 2          01-JAN-2009                  3  37380  38651                 33615
# 3          01-JAN-2009                  4  36426  37775                 32526
# 4          01-JAN-2009                  5  35687  37298                 31877
# ...                ...                ...    ...    ...                   ...
# 262939      31/12/2023                 44  25269  25921                 22546
# 262940      31/12/2023                 45  24254  24977                 21608
# 262941      31/12/2023                 46  23455  24134                 20889
# 262942      31/12/2023                 47  22533  23714                 20081
# 262943      31/12/2023                 48  22093  23732                 19707
#
# ...
